# %%
from openai import AzureOpenAI

def get_completion(prompt, model="gpt-3.5-turbo"):

    client = AzureOpenAI(
        api_key="<KEY>",  
        api_version="2023-12-01-preview",
        azure_endpoint="<Endpoint>"
    )

    response = client.chat.completions.create(
    model=model,
    messages=[
        {
        "role": "user",
        "content": prompt
        }
    ],
    temperature=1,
    max_tokens=256,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
    )

    return response.choices[0].message.content
# Out:
# StatementMeta(, 08a46145-5788-48c4-8231-2db7e775c48c, 42, Finished, Available)

# %%
import requests

def send_teams_message(message:str) -> None:
    request = requests.post(
        url="<URL_KEY>",
        json={
            "body": message
        }
    )
    if request.raise_for_status():
        raise Exception("Error Sending Teams Message")
# Out:
# StatementMeta(, 4044c9ba-c89d-4bc2-8405-43087f915b5a, 7, Finished, Available)
